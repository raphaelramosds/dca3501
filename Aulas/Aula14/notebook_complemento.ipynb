# %% [markdown]
# # Aula 14 - Complemento
#
# - Pré processamento de dados
#
# *Referências*
# - 📖 [Curso Kaggle - Handling Missing Values](https://www.kaggle.com/code/alexisbcook/handling-missing-values)

# %%
#
